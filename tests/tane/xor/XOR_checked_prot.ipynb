# %%
input="""

.model jjmod jj(Rtype=1, Vg=2.8mV, Cap=0.064pF, R0=100ohm, Rn=16ohm, Icrit=0.1mA)
.model pjjmod jj(Rtype=1, Vg=2.8mV, Cap=0.064pF, R0=100ohm, Rn=16ohm, Icrit=0.1mA PHI=PI)
.model jjmod_pi jj(Rtype=1, Vg=2.8mV, Cap=0.064pF, R0=100ohm, Rn=16ohm, Icrit=0.1mA PHI=PI)


*** ZZPSQt_jtl
.subckt ZZPSQt_jtl          1    10
***       Pin
L4                 2         10   0.200pH fcheck
L3                 6         10   0.200pH fcheck
L1                 1         4   1.550pH fcheck
L0                 5         1   1.550pH fcheck
B2                 3         6  jjmod_pi area=100
RS2                3         6  0.04ohm
B1                 4         3  jjmod area=0.608
RS1                4         3  12.71ohm *SHUNT=7.73
B0                 5         2  jjmod area=0.608
RS0                5         2  12.71ohm *SHUNT=7.73
.ends

*** HFQ_JTL
.subckt HFQ_JTL          1          5        13
***       Pin      Pout
X2         ZZPSQt_jtl          6     0
X1         ZZPSQt_jtl          7     0
L5                10        11   2.600pH fcheck
L4                 6         5  3.200pH fcheck
L2                 7         6  8.4pH fcheck
L1                10         7   4.200pH fcheck
L0                 1        10  1.000pH fcheck
R0                13        11  34.0ohm
.ends



*** ijtl
.subckt ijtl          1        11
***       din
L1                1         10  4.534pH
B1                10         9  jjmod area=2.13
RS1               10         9   5.31ohm *SHUNT=11.30
LP2               9         0  0.198pH
L2                10         11  1.976pH
.ends

***SFQ***
.subckt jtl  3 7 1
R1                 1         2   8.32ohm
LPIN               3         4   0.840pH fcheck
LPR1               2         4   3.588pH fcheck
L2                 5         6   4.776pH fcheck
L3                 6         7   1.620pH fcheck
L1                 4         5   2.467pH fcheck
LP2                8         0   0.218pH fcheck
LP1                9         0   0.224pH fcheck
B2                 6         8  jjmod area=2.13
RS2                6         8   11.31ohm *SHUNT=11.30
B1                 5         9  jjmod area=2.13
RS1                5         9   11.31ohm *SHUNT=11.30
.ends




*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI0          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.92
RS1                7         4  11.29ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.92
RS0                6         3  11.29ohm *SHUNT=7.73
.ends

*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI1          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.81
RS1                7         4  13.94ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.81
RS0                6         3  13.94ohm *SHUNT=7.73
.ends

*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI2          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.608
RS1                7         4  18.57ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.608
RS0                6         3  18.57ohm *SHUNT=7.73
.ends

*** cell: StoH
.subckt StoH    35    25    22
Lsq2               8         0   0.200pH fcheck
Lsq1               9         0   0.200pH fcheck
Lsq0              10         0   0.200pH fcheck
LP2               11         0   0.200pH fcheck
LP1               12         0   0.200pH fcheck
LP0               13         0   0.200pH fcheck
Lb5               22        15   2.600pH fcheck
Lb4               22        17   2.600pH fcheck
Lb3               22        19   2.600pH fcheck
Lb2               22        21   2.600pH fcheck
Lb1               22        23   2.600pH fcheck
L12               24        25   3.200pH fcheck
L11               26        24   8.400pH fcheck
L10               27        26   0.500pH fcheck
L9                28        27   5.880pH fcheck
L8                 4        28   3.710pH fcheck
L7                29         4   1.000pH fcheck
L6                30        31   1.000pH fcheck
L5                 3        30   0.500pH fcheck
L4                32         3   9.800pH fcheck
L3                 7        32   0.500pH fcheck
L2                33         7   6.940pH fcheck
L1                34        33   2.467pH fcheck
L0                35        34   0.840pH fcheck
B2                30        11  jjmod area=1.00
RS2               30        11  11.30ohm *SHUNT=11.30
B1                32        12  jjmod area=1.39
RS1               32        12   8.13ohm *SHUNT=11.30
B0                33        13  jjmod area=2.13
RS0               33        13   5.31ohm *SHUNT=11.30
XI2             ZZPSQ_StoH_XI2         24          8
XI1             ZZPSQ_StoH_XI1         26          9
XI0             ZZPSQ_StoH_XI0         28         10
R5                15        27  189.40ohm
R4                17         4  127.60ohm
R3                19         3  45.70ohm *35.70
R2                21         7  25.70ohm
R1                23        34   8.32ohm
R0                31        29   2.50ohm
*** PORT        pin =         35
*** PORT       pout =         25
.ends





** + -------------------- +
** |     XOR_PAIR         |
** + -------------------- +
.subckt xor_squid1   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=0.608
R1                  1       5   20ohm 
B2                  2       5   jjmod area=0.608
R2                  2       5   20ohm
B3                  4       2   pjjmod area=20
R3                  4       2   0.39ohm
.ends

.subckt xor_squid2   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID2(0.608)
R1                  1       5   20ohm 
B2                  2       5   jjmod area=#SQUID2(0.608)
R2                  2       5   20ohm
B3                  4       2   pjjmod area=20
R3                  4       2   0.39ohm
.ends

.subckt xor_squid3   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID3(0.578)
R1                  1       5   20ohm 
B2                  2       5   jjmod area=#SQUID3(0.578)
R2                  2       5   20ohm
B3                  4       2   pjjmod area=20
R3                  4       2   0.39ohm
.ends

.subckt xor_pair        1       7     100
L1                      1       2       1pH
R1                      2       100     34ohm
L2                      2       3       4.2pH
X1      xor_squid1      3       0
L3                      3       4       8.4pH
X2      xor_squid2      4       0
X3      xor_squid3      4       5
L4                      5       6       #L1(13.8)pH
R2                      6       100     #R1(81.4)ohm
L5                      6       7       #L2(8.21)pH
.ends
** + ---------------------------------- +


** + ------------------------------------------------------------------------------------------------------------  +
** |     XOR                                                                                                       |
** + ------------------------------------------------------------------------------------------------------------  +
.subckt xor_squid4   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID4(0.723)
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=#SQUID4(0.723)
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends

.subckt xor_squid5   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID5(0.488)
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=#SQUID5(0.488)
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends

.subckt xor_squid6   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID6(0.548)
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=#SQUID6(0.548)
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends

.subckt xor_squid7   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID7(0.655)
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=#SQUID7(0.655)
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends

.subckt xor_squid8   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=#SQUID8(0.74)
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=#SQUID8(0.74)
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends

.subckt xor_squid9   3       5 
L1                  3       1   1.75pH fcheck
L2                  3       4   1.75pH fcheck
B1                  1       5   jjmod area=2
R1                  1       5   12.71ohm 
B2                  2       5   jjmod area=2
R2                  2       5   12.71ohm
B3                  4       2   pjjmod area=100
R3                  4       2   0.39ohm
.ends


***            a     b     clk   c    bias
.subckt XOR    44    39    36    9    100

X51     xor_pair    44  29  100
X52     xor_pair    39  29  100

** --------- start from input ------------
L1                      29          30   1pH fcheck
X4    xor_squid4        28          30
L2                      28          27   1pH fcheck
L3                      27          26   1pH fcheck
X5    xor_squid5        26         0
L4                      26          8   8.4pH fcheck
X6    xor_squid6        8         0
L5                      8           9   3.2pH fcheck


** --------- start from clk ------------
L11                     36        18   1pH fcheck
R4                      18        100  34ohm
L12                     18        34   4.2pH fcheck
X7   xor_squid7         34         0
L13                     34        35   1pH fcheck
X8   xor_squid8         35         32
L14                     32        33   1pH fcheck
X9   xor_squid9         31         33
L15                     31        27   2pH fcheck
.ends
** + ------------------------------------------------------------------------------------------------------ +






***topcell
***a
X1 ijtl 1 4 
X2 jtl 4 5 200
X3 StoH 5 6 300
X4 HFQ_JTL 6 7 100
X5 HFQ_JTL 7 8 100

***clk
X6 ijtl 2 9 
X7 jtl 9 10 200
X8 StoH 10 11 300
X9 HFQ_JTL 11 12 100
X10 HFQ_JTL 12 13 100

***b
X11 ijtl 3 14 
X12 jtl 14 15 200
X13 StoH 15 16 300
X14 HFQ_JTL 16 17 100
X15 HFQ_JTL 17 18 100



X17 XOR  8  18  13  21  100 




X18 HFQ_JTL 21 24 100
X19 HFQ_JTL 24 25 100
X20 HFQ_JTL 25 26 100
Lend1 26 32 3pH
Rend1 32 0 3ohm



Vb1                100         0 pwl(0ps 0mV 100ps #BIAS(0.5)mV)

Vb3                300         0 pwl(0ps 0mV 100ps 2.5mV)

Vb2                200         0 pwl(0ps 0mV 100ps 2.5mV)


Vclk 2 0 PWL(0ps 0mv      300.0ps 0mv 301.0ps 1.035mv 302.0ps 1.035mv 303.0ps 0mv      500.0ps 0mv 501.0ps 1.035mv 502.0ps 1.035mv 503.0ps 0mv      700.0ps 0mv 701.0ps 1.035mv 702.0ps 1.035mv 703.0ps 0mv      900.0ps 0mv 901.0ps 1.035mv 902.0ps 1.035mv 903.0ps 0mv      1100.0ps 0mv 1101.0ps 1.035mv 1102.0ps 1.035mv 1103.0ps 0mv       1500.0ps 0mv 1501.0ps 1.035mv 1502.0ps 1.035mv 1503.0ps 0mv )

Vdin1 1 0 PWL(0ps 0mv       200.0ps 0mv 201.0ps 1.035mv 202.0ps 1.035mv 203.0ps 0mv      400.0ps 0mv 401.0ps 1.035mv 402.0ps 1.035mv 403.0ps 0mv      800.0ps 0mv 801.0ps 1.035mv 802.0ps 1.035mv 803.0ps 0mv       1400.0ps 0mv 1401.0ps 1.035mv 1402.0ps 1.035mv 1403.0ps 0mv)

Vdin2 3 0 PWL(0ps 0mv       620.0ps 0mv 621.0ps 1.035mv 622.0ps 1.035mv 623.0ps         0mv 820.0ps 0mv 821.0ps 1.035mv 822.0ps 1.035mv 823.0ps 0mv       1420.0ps 0mv 1421.0ps 1.035mv 1422.0ps 1.035mv 1423.0ps 0mv)

**netlis file
.tran 1ps 2000ps 0ps 1ps


.print phase 6|X5
.print phase 6|X10
.print phase 6|X15
.print phase 6|X18
.end

"""



config_data = {
    "avgcalc.start.time":100e-12,
    "avgcalc.end.time":200e-12,
    "pulse.delay":100e-12,
    "pulse.interval": 500e-12,
    "phase.ele": ["P(6|X5)","P(6|X10)","P(6|X15)","P(6|X18)"],
    "voltage.ele" : [],
    "allow.multi.swithes" : False
}

from hfqco import data, util, pyjosim, netlist

from hfqco.pyjosim import simulation
from hfqco.graph import sim_plot
import importlib
importlib.reload(data)
importlib.reload(util)
importlib.reload(netlist)



# df = simulation(input)
# sim_plot(df)

# inp_df = util.create_inp_df("R3",30, 40, 2, "SQUID9", 0.518,0.608,0.03)
d = netlist.Netlist(input, config_data)
# d.get_margins()
# Out:
# ･ (Period to calculate initial phase)		=  1e-10  ~  2e-10 [s]
# ･ (Acceptable switch timing delay)		=  1e-10 [s]
# ･ (Interval between input SFQ or HFQ pulses)	=  5e-10 [s]
# Simulate with default values.
