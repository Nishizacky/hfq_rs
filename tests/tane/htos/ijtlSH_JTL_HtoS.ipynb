# %%
JTL="""
*** ZZPSQt_jtl
.subckt ZZPSQt_jtl          1    10
***       Pin
L4                 2         10   0.200pH fcheck
L3                 6         10   0.200pH fcheck
L1                 1         4   #JTL_SQ_L(2.050)pH fcheck
L0                 5         1   #JTL_SQ_L(2.050)pH fcheck
B2                 3         6  jjmod_pi area=100
RS2                3         6  0.04ohm
B1                 4         3  jjmod area=#JTL_SQ_JJ(0.608)
RS1                4         3  12.71ohm *SHUNT=7.73
B0                 5         2  jjmod area=#JTL_SQ_JJ(0.608)
RS0                5         2  12.71ohm *SHUNT=7.73
.ends

*** HFQ_JTL
.subckt HFQ_JTL          1          5        13
***       Pin      Pout
X2         ZZPSQt_jtl          6     0
X1         ZZPSQt_jtl          7     0
L5                10        11   2.600pH fcheck
L4                 6         5  #JTL_L4(3.200)pH fcheck
L2                 7         6  #JTL_L2(8.4)pH fcheck
L1                10         7   #JTL_L1(4.200)pH fcheck
L0                 1        10  1.000pH fcheck
R0                13        11  #JTL_Rb(34.0)ohm
.ends
"""

# %%
JTL_HtoS="""
*** HtoS_ZZPSQ_jtl
.subckt HtoS_ZZPSQ_jtl          1    10
***       Pin
L4                 2         10   0.200pH fcheck
L3                 6         10   0.200pH fcheck
L1                 1         4   #HtoS_JTL_SQ_L(2.050)pH fcheck
L0                 5         1   #HtoS_JTL_SQ_L(2.050)pH fcheck
B2                 3         6  jjmod_pi area=100
RS2                3         6  0.04ohm
B1                 4         3  jjmod area=#HtoS_JTL_SQ_JJ(0.608)
RS1                4         3  12.71ohm *SHUNT=7.73
B0                 5         2  jjmod area=#HtoS_JTL_SQ_JJ(0.608)
RS0                5         2  12.71ohm *SHUNT=7.73
.ends

*** HtoS_HFQ_JTL
.subckt HtoS_HFQ_JTL          1          5        13
***       Pin      Pout
X2         HtoS_ZZPSQ_jtl          6     0
X1         HtoS_ZZPSQ_jtl          7     0
L5                10        11   2.600pH fcheck
L4                 6         5  #HtoS_JTL_L4(3.200)pH fcheck
L2                 7         6  #HtoS_JTL_L2(8.4)pH fcheck
L1                10         7   #HtoS_JTL_L1(4.200)pH fcheck
L0                 1        10  1.000pH fcheck
R0                13        11  #HtoS_JTL_Rb(34.0)ohm
.ends
"""

# %%
JTL_INOUT="""
*** ZZPSQt_jtl
.subckt ZZPSQ_jtl_inout          1    10
***       Pin
L4                 2         10   0.200pH fcheck
L3                 6         10   0.200pH fcheck
L1                 1         4   1.550pH fcheck
L0                 5         1   1.550pH fcheck
B2                 3         6  jjmod_pi area=100
RS2                3         6  0.04ohm
B1                 4         3  jjmod area=0.608
RS1                4         3  12.71ohm *SHUNT=7.73
B0                 5         2  jjmod area=0.608
RS0                5         2  12.71ohm *SHUNT=7.73
.ends


*** HFQ_JTL_INOUT
.subckt HFQ_JTL_INOUT          1          5        13
***       Pin      Pout
X2         ZZPSQ_jtl_inout          6     0
X1         ZZPSQ_jtl_inout          7     0
L5                10        11   2.600pH fcheck
L4                 6         5  #JTL_L4(3.200)pH fcheck
L2                 7         6  #JTL_L2(8.4)pH fcheck
L1                10         7   #JTL_L1(4.200)pH fcheck
L0                 1        10  1.000pH fcheck
R0                13        11  #JTL_Rb(34.0)ohm
.ends
"""

# %%
ijtlSH="""
*** ijtl
.subckt ijtl          1        11
***       din
L1                1         10  4.534pH
B1                10         9  jjmod area=2.13
RS1               10         9   5.31ohm *SHUNT=11.30
LP2               9         0  0.198pH
L2                10         11  1.976pH
.ends

***SFQ***
.subckt jtl  3 7 1
R1                 1         2   8.32ohm
LPIN               3         4   0.840pH fcheck
LPR1               2         4   3.588pH fcheck
L2                 5         6   4.776pH fcheck
L3                 6         7   1.620pH fcheck
L1                 4         5   2.467pH fcheck
LP2                8         0   0.218pH fcheck
LP1                9         0   0.224pH fcheck
B2                 6         8  jjmod area=2.13
RS2                6         8   5.30ohm *SHUNT=11.30
B1                 5         9  jjmod area=2.13
RS1                5         9   5.30ohm *SHUNT=11.30
.ends

"""

# %%
StoH="""
*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI0          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.92
RS1                7         4  11.29ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.92
RS0                6         3  11.29ohm *SHUNT=7.73
.ends

*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI1          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.81
RS1                7         4  13.94ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.81
RS0                6         3  13.94ohm *SHUNT=7.73
.ends

*** ZZPSQ_StoH
.subckt ZZPSQ_StoH_XI2          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   1.550pH fcheck
L0                 1         6   1.550pH fcheck
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm *SHUNT=7.73
B1                 7         4  jjmod area=0.608
RS1                7         4  18.57ohm *SHUNT=7.73
B0                 6         3  jjmod area=0.608
RS0                6         3  18.57ohm *SHUNT=7.73
.ends

*** cell: StoH
.subckt StoH    35    25    22
Lsq2               8         0   0.200pH fcheck
Lsq1               9         0   0.200pH fcheck
Lsq0              10         0   0.200pH fcheck
LP2               11         0   0.200pH fcheck
LP1               12         0   0.200pH fcheck
LP0               13         0   0.200pH fcheck
Lb5               22        15   2.600pH fcheck
Lb4               22        17   2.600pH fcheck
Lb3               22        19   2.600pH fcheck
Lb2               22        21   2.600pH fcheck
Lb1               22        23   2.600pH fcheck
L12               24        25   3.200pH fcheck
L11               26        24   8.400pH fcheck
L10               27        26   0.500pH fcheck
L9                28        27   5.880pH fcheck
L8                 4        28   3.710pH fcheck
L7                29         4   1.000pH fcheck
L6                30        31   1.000pH fcheck
L5                 3        30   0.500pH fcheck
L4                32         3   9.800pH fcheck
L3                 7        32   0.500pH fcheck
L2                33         7   6.940pH fcheck
L1                34        33   2.467pH fcheck
L0                35        34   0.840pH fcheck
B2                30        11  jjmod area=1.00
RS2               30        11  11.30ohm *SHUNT=11.30
B1                32        12  jjmod area=1.39
RS1               32        12   8.13ohm *SHUNT=11.30
B0                33        13  jjmod area=2.13
RS0               33        13   5.31ohm *SHUNT=11.30
XI2             ZZPSQ_StoH_XI2         24          8
XI1             ZZPSQ_StoH_XI1         26          9
XI0             ZZPSQ_StoH_XI0         28         10
R5                15        27  189.40ohm
R4                17         4  127.60ohm
R3                19         3  45.70ohm *35.70
R2                21         7  25.70ohm
R1                23        34   8.32ohm
R0                31        29   2.50ohm
*** PORT        pin =         35
*** PORT       pout =         25
.ends

"""

# %%
SPL="""

*** ZZPSQ
.subckt ZZPSQ_SPL_I1          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   #SPL_SQ1_L(2.050)pH fcheck
Rsq1               1         5   6.7ohm
L0                 6         1   #SPL_SQ1_L(2.050)pH fcheck
Rsq0               6         1   6.7ohm
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm 
B1                 7         4  jjmod area=#SPL_SQ1_JJ(0.578)
*RS1                7         4  13.37ohm *SHUNT=7.73
B0                 6         3  jjmod area=#SPL_SQ1_JJ(0.578)
*RS0                6         3  13.37ohm *SHUNT=7.73
.ends

*** ZZPSQ
.subckt ZZPSQ_SPL_I2          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   #SPL_SQ2_L(2.050)pH fcheck
Rsq1               1         5   6.7ohm
L0                 6         1   #SPL_SQ2_L(2.050)pH fcheck
Rsq0               6         1   6.7ohm
B2                 5         7  jjmod_pi area=100.00
RS2                5         7   0.04ohm 
B1                 7         4  jjmod area=#SPL_SQ2_JJ(0.49)
*RS1                7         4  13.37ohm *SHUNT=7.73
B0                 6         3  jjmod area=#SPL_SQ2_JJ(0.49)
*RS0                6         3  13.37ohm *SHUNT=7.73
.ends

*** ZZPSQ
.subckt ZZPSQ_SPL_I3          1          2
***       Pin      Pout
L4                 3         2   0.200pH fcheck
L3                 4         2   0.200pH fcheck
L1                 1         5   #SPL_SQ3_L(2.050)pH fcheck
Rsq1               1         5   6.7ohm
L0                 6         1   #SPL_SQ3_L(2.050)pH fcheck
Rsq0               6         1   6.7ohm
B2                 5         7  jjmod_pi area=20.00
RS2                5         7   0.20ohm 
B1                 7         4  jjmod area=#SPL_SQ3_JJ(0.49)
*RS1                7         4  13.37ohm *SHUNT=7.73
B0                 6         3  jjmod area=#SPL_SQ3_JJ(0.49)
*RS0                6         3  13.37ohm *SHUNT=7.73
.ends

***cell SPL
.subckt SPL           19     13     11     21
L10                8         9   2.600pH fcheck
L2                 8        10   1.000pH fcheck
L6                 3        11   #SPL_L6(3.200)pH fcheck
L4                12        13   #SPL_L4(3.200)pH fcheck
L15               14         3   0.001pH fcheck
L14               15        12   0.001pH fcheck
L5                10         3   #SPL_L5(4.000)pH fcheck
L1                 7         8   #SPL_L1(1.000)pH fcheck
L3                10        12   #SPL_L3(4.000)pH fcheck
L13               16         7   0.001pH fcheck
L0                17         7   #SPL_L0(4.200)pH fcheck
L16               17        18   2.600pH fcheck
Ldin              19        17   1.000pH fcheck
R2                21         9  #SPL_R2(25.00)ohm
R1                21        18  #SPL_R1(25.00)ohm
XI3             ZZPSQ_SPL_I3         14          0
XI2             ZZPSQ_SPL_I2         15          0
XI1             ZZPSQ_SPL_I1         16          0
*** PORT        din =         19
*** PORT      dout1 =         13
*** PORT      dout2 =         11
.ends

"""

# %%
sfqincrease="""
***cell: sfqincrease
.subckt sfqincrease    22    29    27
***                    pin   pout  bias
Lp6                1         0   2.600pH fcheck
Lp5                2         0   2.600pH fcheck
Lp4                3         0   2.600pH fcheck
Lp3                4         0   2.600pH fcheck
Lp2                5         0   2.600pH fcheck
Lp1                6         0   2.600pH fcheck
Lp0                7         0   2.600pH fcheck
Lb4                8         9   2.600pH fcheck
Lb3               10        11   2.600pH fcheck
Lb2               12        13   2.600pH fcheck
Lb1               14        15   2.600pH fcheck
Lb0               16        17   2.600pH fcheck
L8                18        19   1.620pH fcheck
L7                20        18   4.779pH fcheck
L6                 9        20   2.616pH fcheck
L5                21         9   3.029pH fcheck
L4                11        21   2.779pH fcheck
L3                13        11   7.048pH fcheck
L2                15        13  10.010pH fcheck
L1                17        15  14.000pH fcheck
L0                22        17   2.450pH fcheck
B6                18         1  jjmod area=2.13
RS6               18         1   5.30ohm *SHUNT=3.73
B5                20         2  jjmod area=2.13
RS5               20         2   5.30ohm *SHUNT=3.73
B4                21         3  jjmod area=2.13
RS4               21         3   5.30ohm *SHUNT=3.73
B3                11         4  jjmod area=1.49
*RS3               11         4   2.51ohm *SHUNT=3.73
B2                13         5  jjmod area=1.00
*RS2               13         5   3.73ohm *SHUNT=3.73
B1                15         6  jjmod area=0.74
*RS1               15         6   5.05ohm *SHUNT=3.73
B0                17         7  jjmod area=0.49
*RS0               17         7   7.62ohm *SHUNT=3.73
R4                27         8   8.32ohm
R3                27        10  20.08ohm
R2                27        12  30.08ohm
R1                27        14  40.08ohm
R0                27        16  60.08ohm
*** PORT        pin =         22
*** PORT       pout =         19
.ends

"""

# %%
HtoS="""

***cell HtoS_bySPL
.subckt HtoS_bySPL 1 21 100 200
X0 HtoS_HFQ_JTL 1 2 100
X1 SPL 2 3 4 100
X2 HtoS_HFQ_JTL 3 5 100
X3 HtoS_HFQ_JTL 4 6 100
X4 SPL 5 7 8 100
X5 SPL 6 9 10 100
L0 7 11    1pH
L1 8 12    1pH
L2 9 13    1pH
L3 10 14    1pH
R0 11 15    1ohm
R1 12 16    1ohm
R2 13 17    1ohm
R3 14 18    1ohm
L4 15 19    9.80pH
L5 16 19    9.80pH
L6 17 19    9.80pH
L7 18 19    9.80pH
L8 19 20    0.001pH
X6 sfqincrease 20 21 200
.ends

"""

# %%
netlist="""
.model jjmod jj(Rtype=1, Vg=2.8mV, Cap=0.064pF, R0=100ohm, Rn=16ohm, Icrit=0.1mA)
.model jjmod_pi jj(Rtype=1, Vg=2.8mV, Cap=0.004pF, R0=100ohm, Rn=16ohm, Icrit=0.1mA PHI=PI)

"""+StoH+"""

"""+JTL+"""

"""+JTL_HtoS+"""

"""+JTL_INOUT+"""

"""+SPL+"""

"""+sfqincrease+"""

"""+HtoS+"""


"""+ijtlSH+"""


***topcell
X1 ijtl 1 3
X2 jtl 3 4 200
X3 jtl 4 5 200
X4 jtl 5 6 200
X5 jtl 6 7 200
X6 jtl 7 8 200


X10 StoH 8 9 200


X18 HFQ_JTL 9 24 100
X19 HFQ_JTL 24 25 100
X20 HFQ_JTL 25 26 100
X21 HFQ_JTL 26 27 100
X22 HFQ_JTL 27 73 100


X23 HtoS_bySPL 73 74 300 400


X84 jtl 74 75 500
X85 jtl 75 76 500
X86 jtl 76 77 500
X87 jtl 77 78 500
X88 jtl 78 79 500
Lend1 79 80 #Lend(1)pH
Rend1 80 0 #Rend(1)ohm



Vb1                100         0 pwl(0ps 0mV 1000ps #BIAS_H(0.7)mV)

Vb2                200         0 pwl(0ps 0mV 1000ps #BIAS_S(2.5)mV)

Vb3                300         0 pwl(0ps 0mV 1000ps #BIAS_HtoS_H(0.7)mV)

Vb4                400         0 pwl(0ps 0mV 1000ps #BIAS_HtoS_S(2.2)mV)

Vb5                500         0 pwl(0ps 0mV 1000ps #BIAS_S2(2.2)mV)

*Vdin 1 0 PWL(0ps 0mv)
*Vdin 1 0 PWL(0ps 0mv 1500ps 0mv 1501ps 1.035mv 1502ps 1.035mv 1503ps 0mv 1700ps 0mv 1701ps 1.035mv 1702ps 1.035mv 1703ps 0mv 1900ps 0mv 1901ps 1.035mv 1902ps 1.035mv 1903ps 0mv 2100ps 0mv 2101ps 1.035mv 2102ps 1.035mv 2103ps 0mv 2300ps 0mv 2301ps 1.035mv 2302ps 1.035mv 2303ps 0mv 2500ps 0mv 2501ps 1.035mv 2502ps 1.035mv 2503ps 0mv 2700ps 0mv 2701ps 1.035mv 2702ps 1.035mv 2703ps 0mv 2900ps 0mv 2901ps 1.035mv 2902ps 1.035mv 2903ps 0mv 3100ps 0mv 3101ps 1.035mv 3102ps 1.035mv 3103ps 0mv 3300ps 0mv 3301ps 1.035mv 3302ps 1.035mv 3303ps 0mv 3500ps 0mv 3501ps 1.035mv 3502ps 1.035mv 3503ps 0mv 3700ps 0mv 3701ps 1.035mv 3702ps 1.035mv 3703ps 0mv 3900ps 0mv 3901ps 1.035mv 3902ps 1.035mv 3903ps 0mv 4100ps 0mv 4101ps 1.035mv 4102ps 1.035mv 4103ps 0mv 4300ps 0mv 4301ps 1.035mv 4302ps 1.035mv 4303ps 0mv 4500ps 0mv 4501ps 1.035mv 4502ps 1.035mv 4503ps 0mv 4700ps 0mv 4701ps 1.035mv 4702ps 1.035mv 4703ps 0mv 4900ps 0mv 4901ps 1.035mv 4902ps 1.035mv 4903ps 0mv 5100ps 0mv 5101ps 1.035mv 5102ps 1.035mv 5103ps 0mv 5300ps 0mv 5301ps 1.035mv 5302ps 1.035mv 5303ps 0mv 5500ps 0mv 5501ps 1.035mv 5502ps 1.035mv 5503ps 0mv 5700ps 0mv 5701ps 1.035mv 5702ps 1.035mv 5703ps 0mv 5900ps 0mv 5901ps 1.035mv 5902ps 1.035mv 5903ps 0mv 6100ps 0mv 6101ps 1.035mv 6102ps 1.035mv 6103ps 0mv 6300ps 0mv 6301ps 1.035mv 6302ps 1.035mv 6303ps 0mv 6500ps 0mv 6501ps 1.035mv 6502ps 1.035mv 6503ps 0mv 6700ps 0mv 6701ps 1.035mv 6702ps 1.035mv 6703ps 0mv 6900ps 0mv 6901ps 1.035mv 6902ps 1.035mv 6903ps 0mv 7100ps 0mv 7101ps 1.035mv 7102ps 1.035mv 7103ps 0mv 7300ps 0mv 7301ps 1.035mv 7302ps 1.035mv 7303ps 0mv 7500ps 0mv 7501ps 1.035mv 7502ps 1.035mv 7503ps 0mv 7700ps 0mv 7701ps 1.035mv 7702ps 1.035mv 7703ps 0mv 7900ps 0mv 7901ps 1.035mv 7902ps 1.035mv 7903ps 0mv 8100ps 0mv 8101ps 1.035mv 8102ps 1.035mv 8103ps 0mv 8300ps 0mv 8301ps 1.035mv 8302ps 1.035mv 8303ps 0mv 8500ps 0mv 8501ps 1.035mv 8502ps 1.035mv 8503ps 0mv 8700ps 0mv 8701ps 1.035mv 8702ps 1.035mv 8703ps 0mv 8900ps 0mv 8901ps 1.035mv 8902ps 1.035mv 8903ps 0mv 9100ps 0mv 9101ps 1.035mv 9102ps 1.035mv 9103ps 0mv 9300ps 0mv 9301ps 1.035mv 9302ps 1.035mv 9303ps 0mv )
*Vdin 1 0 PWL(0ps 0mv 1500ps 0mv 1501ps 1.035mv 1502ps 1.035mv 1503ps 0mv 1700ps 0mv 1701ps 1.035mv 1702ps 1.035mv 1703ps 0mv 1900ps 0mv 1901ps 1.035mv 1902ps 1.035mv 1903ps 0mv 2100ps 0mv 2101ps 1.035mv 2102ps 1.035mv 2103ps 0mv 2300ps 0mv 2301ps 1.035mv 2302ps 1.035mv 2303ps 0mv 2500ps 0mv 2501ps 1.035mv 2502ps 1.035mv 2503ps 0mv 2700ps 0mv 2701ps 1.035mv 2702ps 1.035mv 2703ps 0mv 2900ps 0mv 2901ps 1.035mv 2902ps 1.035mv 2903ps 0mv 3100ps 0mv 3101ps 1.035mv 3102ps 1.035mv 3103ps 0mv 3300ps 0mv 3301ps 1.035mv 3302ps 1.035mv 3303ps 0mv )
Vdin 1 0 PWL(0ps 0mv 1500ps 0mv 1501ps 1.035mv 1502ps 1.035mv 1503ps 0mv 2500ps 0mv 2501ps 1.035mv 2502ps 1.035mv 2503ps 0mv 3500ps 0mv 3501ps 1.035mv 3502ps 1.035mv 3503ps 0mv 4500ps 0mv 4501ps 1.035mv 4502ps 1.035mv 4503ps 0mv 5500ps 0mv 5501ps 1.035mv 5502ps 1.035mv 5503ps 0mv )
*Vdin 1 0 PWL(0ps 0mv 1500ps 0mv 1501ps 1.035mv 1502ps 1.035mv 1503ps 0mv )

**netlis file
*.tran 0.01ps 6000ps 0ps 0.01ps
*.tran 0.1ps 1700ps 1500ps 0.1ps
*.tran 0.1ps 6000ps 0ps 0.1ps
.tran 0.1ps 9000ps 0ps 0.1ps

.print devi L8|X23
.print devi B4|X6|X23
.print devi B5|X6|X23
.print devi B6|X6|X23
*.print devi L10|X23
*.print devi Lp0|X23

*.print v(7.X20)
*print v(6.X20)

*print devv B0|XI1|X18
*print devi B1|XI1|X18
*print devi B0|XI1|X42
*print devi B1|XI1|X42
*print devi B0|XI1|X67
*print devi B1|XI1|X67

.end


"""
config_data={
    "avgcalc.pre_start.time":1100e-12,
    "avgcalc.pre_end.time":1400e-12,
    "avgcalc.start.time":1100e-12,
    "avgcalc.end.time":1400e-12,
    "pulse.delay":100e-12,
    "pulse.interval":200e-12,
    "phase.ele":[["B1|X5"],["B0|X2|X18","B1|X2|X18"],["B0|X1|X22","B1|X1|X22"],["B0|X2|X0|X23","B1|X2|X0|X23"],["B0|X1|X0|X23","B1|X1|X0|X23"],["B1|X6|X23"],["B2|X6|X23"],["B3|X6|X23"],["B4|X6|X23"],["B5|X6|X23"],["B6|X6|X23"],["B1|X84"]],
    "voltage.ele":[],
    "current.ele":[],
    "allow.multi.swithes":False,
    "state_judge":False
}

#"phase.ele":[["B0|X6|X2","B1|X6|X2"],["B0|X6|X15","B1|X6|X15"],["B0|X1|X15","B1|X1|X15"],["B0|X1|X18","B1|X1|X18"],["B1|X5|X11","B2|X5|X11"],["B1|X5|X13","B2|X5|X13"],["B0|X3|X19","B1|X3|X19"],["B0|X4|X19","B1|X4|X19"],["B0|X4|X29","B1|X4|X29"]],

from hfqco import data, util
import importlib
importlib.reload(data)
importlib.reload(util)
import pandas as pd

d3 = data.Data(netlist, config_data)
ll = d3.get_base_switch_timing()
for l in ll:
    print(l)
df_ll=pd.DataFrame(ll)
d3.data_simulation().to_csv("./data_simu.csv")
#d3.get_margins().to_csv("./margins.csv")
#print(type(df_ll))
#df_ll.to_csv("/home/nakayama_tora/nakayama/SWITCH_TIME_SHIFT/for_app_physic/ZZP_SW_101_L028pH.csv")
#print('(Avarage propagation delay)='+str(d3.only_get_propagation_time_defference('P(B0|XI1|X18+B1|XI1|X18)','P(B0|XI1|X68+B1|XI1|X68)',10)))
#params=pd.read_csv("/home/nakayama_tora/nakayama/SWITCH_TIME_SHIFT/for_app_physic/vary_param/vary_L_of_ZZPSQ/params_L_of_ZZPSQ.csv",index_col=0)
#print(params)
#after_params=d3.custom_get_propagation_time_defferences_async('P(B0|XI1|X18+B1|XI1|X18)','P(B0|XI1|X68+B1|XI1|X68)', 10, params)
#after_params.to_csv("/home/nakayama_tora/nakayama/SWITCH_TIME_SHIFT/for_app_physic/vary_param/vary_L_of_ZZPSQ/params_L_of_ZZPSQ_after.csv")
# Out:
# ･ (Period to calculate initial phase)		=  1.1e-09  ~  1.4e-09 [s]
# ･ (Acceptable switch timing delay)		=  1e-10 [s]
# ･ (Interval between input SFQ or HFQ pulses)	=  2e-10 [s]
# []
# Simulate with default values.
# {'time': 1.5165e-09, 'phase': 1, 'element': 'P(B1|X5)'}
# {'time': 2.5165e-09, 'phase': 2, 'element': 'P(B1|X5)'}
# {'time': 3.5165e-09, 'phase': 3, 'element': 'P(B1|X5)'}
# {'time': 4.5165e-09, 'phase': 4, 'element': 'P(B1|X5)'}
# {'time': 5.5165e-09, 'phase': 5, 'element': 'P(B1|X5)'}
# {'time': 1.5445e-09, 'phase': 1, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# {'time': 1.6767e-09, 'phase': 2, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# {'time': 2.5445e-09, 'phase': 3, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# {'time': 2.6806e-09, 'phase': 4, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# {'time': 3.5445e-09, 'phase': 5, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# {'time': 3.6806e-09, 'phase': 6, 'element': 'P(B0|X2|X18+B1|X2|X18)'}
# ...
